# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'':
  os.chdir(r'')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# C:\Users\kerry\AppData\Local\Temp\ipykernel_3868\1140549349.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)
# {"C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap_external.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\codecs.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\aliases.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\utf_8.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\cp1252.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\io.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\stat.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_collections_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\genericpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\os.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_sitebuiltins.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_distutils_hack\\__init__.py": 1665541945.6758869, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\types.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\warnings.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\keyword.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\operator.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\reprlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\functools.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\contextlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\util.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\machinery.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib\\pywin32_bootstrap.py": 1665545610.7738168, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\runpy.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\enum.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_constants.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_parse.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_compile.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\copyreg.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\re.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\typing.py": 1665532704.0, "C:\\Users\\kerry\\AppData\ ...

# %%
from pandas_datareader import DataReader as pdr
import plotly.graph_objects as go
import numpy as np

spy = pdr('SPY', 'yahoo', start=1990)['Adj Close']
spy = spy.resample('Y').last()
spy = spy.pct_change().dropna()
spy.index = spy.index.to_period('Y').astype(str)
spy = spy.reset_index()
spy.columns = ['date', 'ret']

trace = go.Scatter(
    x=spy.date,
    y=spy.ret,
        hovertemplate="%{x}<br>%{y:.1%}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="",
    yaxis_tickformat=".0%",
    width=1000,
    height=460,
  )
fig.update_xaxes(title_font_size=24)
fig.update_yaxes(title_font_size=24)
fig.update_layout(font_size=20)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="38c476e3-40a2-4658-a015-7fcf7633b12f" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38c476e3-40a2-4658-a015-7fcf7633b12f")) {                    Plotly.newPlot(                        "38c476e3-40a2-4658-a015-7fcf7633b12f",                        [{"hovertemplate":"%{x}<br>%{y:.1%}<extra></extra>","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"y":[0.003973445447384316,0.38048915188301935,0.22497490534788933,0.3347501285158707,0.2869255763047669,0.20389333274058763,-0.0974148791818914,-0.11758552586949056,-0.2158461757326453,0.2818152892535619,0.10697950162257253,0.04828287938446474,0.15845205362636383,0.05146260786492429,-0.36795003888133326,0.2635177400859683,0.15056146183782215,0.018949427315235745,0.15990375464002082,0.3230777034727863,0.13463792709011457,0.01234277369120762,0.11997918237501937,0.21705407874612925,-0.04568998560465498,0.31223833770909604,0.18331641126806586,0.28728768193342535,-0.21526872696348398],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666 ...

# %%
compound = (1+spy.ret).cumprod()

trace = go.Scatter(
    x=spy.date,
    y=compound,
        hovertemplate="%{x}<br>$%{y:.2f}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation from $1",
    yaxis_tickformat=".0f",
    width=1000,
    height=460,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="right", 
        x=0.99
    )
  )
fig.update_xaxes(title_font_size=24)
fig.update_yaxes(title_font_size=24)
fig.update_layout(font_size=20)

fig.show()
# Out:
# <div>                            <div id="eeb9c719-370b-41a2-be9f-7bb111ec0be5" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeb9c719-370b-41a2-be9f-7bb111ec0be5")) {                    Plotly.newPlot(                        "eeb9c719-370b-41a2-be9f-7bb111ec0be5",                        [{"hovertemplate":"%{x}<br>$%{y:.2f}<extra></extra>","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"y":[1.0039734454473843,1.3859744502187323,1.6977839209712846,2.266117306708601,2.9163243209101726,3.5109434060529785,3.1689252783378694,2.7963055330433892,2.1927336775559376,2.810679553152391,3.1113646509693886,3.2615902951332307,3.7783959754849095,3.9728420859296976,2.511034685942468,3.1727368716595064,3.6504287730833203,3.719602307788308,4.314380682571344,5.708260885403846,6.476809298304202,6.55675108971428,7.343424724494716,8.937345012911464,8.528997847927705,11.19207795828911,13.243769524235091,17.048541370913135,13.378523573412375],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...

# %%
r1 = np.cumprod([1] + 51*[1.1])
r2 = np.cumprod([1] + 30*[1.02] + 21*[1.1])
years = np.arange(1970, 2022)

trace1 = go.Scatter(
  x=years,
  y=r1,
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=r2,
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>accum = %{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickprefix="$", 
    yaxis_tickformat=",.0f",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    )
)

fig.show()
# Out:
# <div>                            <div id="d671a27d-f811-4030-b399-903d46f2eafd" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d671a27d-f811-4030-b399-903d46f2eafd")) {                    Plotly.newPlot(                        "d671a27d-f811-4030-b399-903d46f2eafd",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.1,1.2100000000000002,1.3310000000000004,1.4641000000000006,1.6105100000000008,1.771561000000001,1.9487171000000014,2.1435888100000016,2.357947691000002,2.5937424601000023,2.853116706110003,3.1384283767210035,3.4522712143931042,3.797498335832415,4.177248169415656,4.594972986357222,5.054470284992944,5.559917313492239,6.115909044841463,6.72749994932561,7.400249944258172,8.140274938683989,8.954302432552389,9.849732675807628,10.834705943388391,11.91817653772723,13.109994191499954,14.420993610649951,15.863092971714948,17.449402268886445,19.19434249577509,21.1137767453526,23.22515441988786,25.54766986187665,28.102436848064315,30.91268053287075,34.003948586157826,37.40434344477361,41.14477778925097,45.25925556817607,49.785181124993684,54.76369923749306,60.24006916124237,66.26407607736661,72.89048368510328,80.17953205361361,88.19748525897498,97.01723378487249,106.71895716335975,117.39085287969573,129.1299381676653],"type":"scatter","hovertemplate":"year %{x}<br>accum = %{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.02,1.0404,1.061208,1.08243216,1.1040808032,1.126162419264,1.14868566764928,1.1716593810022657,1.195092568622311,1.2189944199947573,1.2433743083946525,1.2682417945625455,1.2936066304537963,1.3194787630628724,1.3458683383241299,1.3727857050906125,1.4002414191924248,1.4282462475762734,1.4568111725277988,1.485947395978355,1.515666343897922,1.5459796707758806,1.5768992641913981,1.6084372494752261,1.6406059944647307,1.6734181143540252,1.7068864766411058,1.741024206173928,1.7758446902974065,1.8113615841033548,1.9924977425136905,2.1917475167650595,2.4109222684415657,2.6520144952857225,2.917215944814295,3.2089375392957247,3.5298312932252975,3.8828144225478276,4.271095864802611,4.698205451282872,5.16802599641116,5.684828596052276,6.253311455657505,6.878642601223255,7.566506861345581,8.32315754748014,9.155473302228154,10.07102063245097,11.078122695696068,12.185934965265677,13.404528461792246],"type":"scatter","hovertemplate":"year %{x}<br>accum = %{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""}, ...

# %%
trace1 = go.Scatter(
  x=years,
  y=np.log10(r1),
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=np.log10(r2),
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>log = %{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Log of Accumulation",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=",.1f",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    )
)

fig.show()
# Out:
# <div>                            <div id="37501a85-adbf-4051-8963-b898c2ea513b" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37501a85-adbf-4051-8963-b898c2ea513b")) {                    Plotly.newPlot(                        "37501a85-adbf-4051-8963-b898c2ea513b",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.0,0.04139268515822508,0.08278537031645015,0.12417805547467525,0.16557074063290034,0.20696342579112542,0.2483561109493505,0.2897487961075756,0.3311414812658006,0.3725341664240257,0.4139268515822508,0.45531953674047587,0.49671222189870096,0.538104907056926,0.5794975922151511,0.6208902773733762,0.6622829625316012,0.7036756476898263,0.7450683328480513,0.7864610180062764,0.8278537031645015,0.8692463883227265,0.9106390734809516,0.9520317586391767,0.9934244437974017,1.0348171289556267,1.0762098141138519,1.1176024992720768,1.158995184430302,1.200387869588527,1.2417805547467522,1.2831732399049771,1.3245659250632023,1.3659586102214274,1.4073512953796523,1.4487439805378775,1.4901366656961026,1.5315293508543275,1.5729220360125526,1.6143147211707778,1.6557074063290027,1.6971000914872278,1.738492776645453,1.7798854618036781,1.821278146961903,1.8626708321201282,1.9040635172783533,1.9454562024365782,1.9868488875948034,2.0282415727530285,2.0696342579112534,2.111026943069479],"type":"scatter","hovertemplate":"year %{x}<br>log = %{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.0,0.00860017176191757,0.017200343523835118,0.025800515285752654,0.034400687047670235,0.04300085880958781,0.05160103057150539,0.060201202333422944,0.06880137409534054,0.0774015458572581,0.08600171761917567,0.09460188938109323,0.1032020611430108,0.11180223290492833,0.12040240466684593,0.1290025764287635,0.13760274819068108,0.14620291995259865,0.15480309171451626,0.16340326347643377,0.17200343523835138,0.18060360700026898,0.18920377876218655,0.1978039505241041,0.20640412228602167,0.21500429404793922,0.22360446580985677,0.23220463757177437,0.24080480933369194,0.2494049810956095,0.25800515285752706,0.29939783801575215,0.34079052317397723,0.38218320833220226,0.42357589349042735,0.46496857864865243,0.5063612638068775,0.5477539489651025,0.5891466341233277,0.6305393192815527,0.6719320044397779,0.7133246895980029,0.754717374756228,0.796110059914453,0.8375027450726781,0.8788954302309032,0.9202881153891282,0.9616808005473533,1.0030734857055783,1.0444661708638034,1.0858588560220286,1.1272515411802537],"type":"scatter","hovertemplate":"year %{x}<br>log = %{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"c ...

# %%
trace1 = go.Scatter(
  x=years,
  y=r1,
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=r2,
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>log = %{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation ($)",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_type="log",
    yaxis_tickformat=",.0f",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    ),
    yaxis = dict(
        tickmode = 'array',
        tickvals = [1, 2, 5, 10, 20, 50, 100],
    )
)

fig.show()
# Out:
# <div>                            <div id="f0b92ee3-5060-413b-92dc-75df4e2284d4" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0b92ee3-5060-413b-92dc-75df4e2284d4")) {                    Plotly.newPlot(                        "f0b92ee3-5060-413b-92dc-75df4e2284d4",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.1,1.2100000000000002,1.3310000000000004,1.4641000000000006,1.6105100000000008,1.771561000000001,1.9487171000000014,2.1435888100000016,2.357947691000002,2.5937424601000023,2.853116706110003,3.1384283767210035,3.4522712143931042,3.797498335832415,4.177248169415656,4.594972986357222,5.054470284992944,5.559917313492239,6.115909044841463,6.72749994932561,7.400249944258172,8.140274938683989,8.954302432552389,9.849732675807628,10.834705943388391,11.91817653772723,13.109994191499954,14.420993610649951,15.863092971714948,17.449402268886445,19.19434249577509,21.1137767453526,23.22515441988786,25.54766986187665,28.102436848064315,30.91268053287075,34.003948586157826,37.40434344477361,41.14477778925097,45.25925556817607,49.785181124993684,54.76369923749306,60.24006916124237,66.26407607736661,72.89048368510328,80.17953205361361,88.19748525897498,97.01723378487249,106.71895716335975,117.39085287969573,129.1299381676653],"type":"scatter","hovertemplate":"year %{x}<br>log = %{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.02,1.0404,1.061208,1.08243216,1.1040808032,1.126162419264,1.14868566764928,1.1716593810022657,1.195092568622311,1.2189944199947573,1.2433743083946525,1.2682417945625455,1.2936066304537963,1.3194787630628724,1.3458683383241299,1.3727857050906125,1.4002414191924248,1.4282462475762734,1.4568111725277988,1.485947395978355,1.515666343897922,1.5459796707758806,1.5768992641913981,1.6084372494752261,1.6406059944647307,1.6734181143540252,1.7068864766411058,1.741024206173928,1.7758446902974065,1.8113615841033548,1.9924977425136905,2.1917475167650595,2.4109222684415657,2.6520144952857225,2.917215944814295,3.2089375392957247,3.5298312932252975,3.8828144225478276,4.271095864802611,4.698205451282872,5.16802599641116,5.684828596052276,6.253311455657505,6.878642601223255,7.566506861345581,8.32315754748014,9.155473302228154,10.07102063245097,11.078122695696068,12.185934965265677,13.404528461792246],"type":"scatter","hovertemplate":"year %{x}<br>log = %{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"col ...

# %%
trace = go.Scatter(
    x=spy.date,
    y=compound,
        hovertemplate="%{x}<br>$%{y:.2f}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation from $1",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0f",
    yaxis_type="log",
    width=1000,
    height=460,
    yaxis = dict(
        tickmode = 'array',
        tickvals = [2, 5, 10, 16],
    )
  )

fig.show()
# Out:
# <div>                            <div id="c660eab3-6580-4c53-b42e-f64807d39930" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c660eab3-6580-4c53-b42e-f64807d39930")) {                    Plotly.newPlot(                        "c660eab3-6580-4c53-b42e-f64807d39930",                        [{"hovertemplate":"%{x}<br>$%{y:.2f}<extra></extra>","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"y":[1.0039734454473843,1.3859744502187323,1.6977839209712846,2.266117306708601,2.9163243209101726,3.5109434060529785,3.1689252783378694,2.7963055330433892,2.1927336775559376,2.810679553152391,3.1113646509693886,3.2615902951332307,3.7783959754849095,3.9728420859296976,2.511034685942468,3.1727368716595064,3.6504287730833203,3.719602307788308,4.314380682571344,5.708260885403846,6.476809298304202,6.55675108971428,7.343424724494716,8.937345012911464,8.528997847927705,11.19207795828911,13.243769524235091,17.048541370913135,13.378523573412375],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...

# %%
trace = go.Box(
    x=spy.ret,
    text=spy.date,
    hovertemplate="%{text}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    yaxis_title="",
    xaxis_title="Annual Return",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat="",
    width=1000,
    height=500,
)

fig.show()
# Out:
# <div>                            <div id="5308e2d8-3ecc-4f11-9290-8f12a229bdb0" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5308e2d8-3ecc-4f11-9290-8f12a229bdb0")) {                    Plotly.newPlot(                        "5308e2d8-3ecc-4f11-9290-8f12a229bdb0",                        [{"hovertemplate":"%{text}<extra></extra>","name":"","text":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"x":[0.003973445447384316,0.38048915188301935,0.22497490534788933,0.3347501285158707,0.2869255763047669,0.20389333274058763,-0.0974148791818914,-0.11758552586949056,-0.2158461757326453,0.2818152892535619,0.10697950162257253,0.04828287938446474,0.15845205362636383,0.05146260786492429,-0.36795003888133326,0.2635177400859683,0.15056146183782215,0.018949427315235745,0.15990375464002082,0.3230777034727863,0.13463792709011457,0.01234277369120762,0.11997918237501937,0.21705407874612925,-0.04568998560465498,0.31223833770909604,0.18331641126806586,0.28728768193342535,-0.21526872696348398],"type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...

# %%
from scipy.stats import norm
from scipy.stats import gaussian_kde as kde

density = kde(spy.ret)
grid = np.linspace(np.min(spy.ret), np.max(spy.ret), 100)

trace1 = go.Scatter(
  x=grid,
  y=density(grid),
  mode="lines",
  name="actual"
)

trace2 = go.Scatter(
  x=grid, 
  y=norm.pdf(grid, np.mean(spy.ret), scale=np.std(spy.ret)), 
  mode="lines", 
  name="normal"
)
fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="Annual Return",
    yaxis_title="",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat="",
    width=1000,
    height=360,
     legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="right", 
        x=0.99
    ),
)

fig.show()
# Out:
# <div>                            <div id="d15a7605-d97f-4d5b-bc3b-96454f267c50" class="plotly-graph-div" style="height:360px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d15a7605-d97f-4d5b-bc3b-96454f267c50")) {                    Plotly.newPlot(                        "d15a7605-d97f-4d5b-bc3b-96454f267c50",                        [{"mode":"lines","name":"actual","x":[-0.36795003888133326,-0.3603900470554307,-0.35283005522952815,-0.3452700634036256,-0.33771007157772304,-0.33015007975182054,-0.3225900879259179,-0.3150300961000154,-0.30747010427411287,-0.2999101124482103,-0.29235012062230775,-0.2847901287964052,-0.27723013697050264,-0.2696701451446001,-0.2621101533186975,-0.25455016149279497,-0.24699016966689244,-0.23943017784098988,-0.23187018601508733,-0.2243101941891848,-0.21675020236328224,-0.20919021053737968,-0.20163021871147713,-0.19407022688557457,-0.186510235059672,-0.17895024323376948,-0.17139025140786693,-0.16383025958196437,-0.15627026775606181,-0.14871027593015926,-0.14115028410425673,-0.13359029227835417,-0.12603030045245162,-0.11847030862654906,-0.1109103168006465,-0.10335032497474395,-0.09579033314884139,-0.08823034132293883,-0.08067034949703633,-0.07311035767113377,-0.06555036584523122,-0.05799037401932866,-0.050430382193426104,-0.04287039036752355,-0.03531039854162099,-0.027750406715718434,-0.020190414889815878,-0.01263042306391332,-0.005070431238010764,0.002489560587891737,0.010049552413794294,0.01760954423969685,0.025169536065599407,0.032729527891501964,0.04028951971740452,0.04784951154330708,0.055409503369209634,0.06296949519511219,0.07052948702101475,0.07808947884691725,0.0856494706728198,0.09320946249872236,0.10076945432462492,0.10832944615052748,0.11588943797643003,0.12344942980233259,0.13100942162823515,0.13856941345413765,0.14612940528004026,0.15368939710594276,0.16124938893184537,0.16880938075774787,0.17636937258365049,0.183929364409553,0.1914893562354556,0.1990493480613581,0.2066093398872606,0.2141693317131632,0.22172932353906571,0.22928931536496833,0.23684930719087083,0.24440929901677344,0.25196929084267594,0.25952928266857855,0.26708927449448105,0.27464926632038367,0.28220925814628617,0.28976924997218867,0.2973292417980913,0.3048892336239938,0.3124492254498964,0.3200092172757989,0.3275692091017015,0.335129200927604,0.3426891927535066,0.3502491845794091,0.35780917640531174,0.36536916823121424,0.37292916005711674,0.38048915188301935],"y":[0.2323644562583101,0.24436594276579648,0.2566038010906875,0.26910965569424494,0.281916611324512,0.29505732822236486,0.3085621359200854,0.3224573092177749,0.33676362289660405,0.35149528653054973,0.36665933823717073,0.38225554778217263,0.39827684701156996,0.4147102713462192,0.43153836240849197,0.4487409511008203,0.4662972147470623,0.48418788298783755,0.5023974562296337,0.5209162982312513,0.5397424708910514,0.5588831938900465,0.5783558334279981,0.5981883513135107,0.6184191762945999,0.639096491762095,0.6602769658503412,0.6820239796646319,0.7044054352983571,0.7274912462059938,0.7513506274788899,0.7760493121137718,0.8016468213117975,0.8281939123628305,0.8557303171927338,0.8842828688419545,0.9138640928407088,0.9444713166304475,0.9760863239471265,1.0086755536156322,1.0421908147658419,1.076570464377521,1.1117409696168057,1.1476187579301653,1.1841122435011693,1.221123910458682,1.2585523318890008,1.2962940096245696,1.33424493289497,1.3723017736755307,1.4103626618884941,1.4483275129522397,1.486097911582062,1.5235765869902882,1.5606665433738918,1.5972699335615084,1.6332867809609297,1.668613664035193,1.703142477626386,1.736759376490684,1.7693439891602485,1.8007689662304787,1.8308998985612701,1.8595956103231348,1.886708802184633,1.9120869940511118,1.9355736971244817,1.9570097335754697,1.976234619930883,1.993087937585704,2.007410629895682,2.019046188421038,2.0278417186397277,2.0336489048 ...

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt
plt.style.use('classic')
plt.rcParams.update({'font.size': 26})
fig = plot_acf(spy.ret)
plt.xlabel("Year")
plt.ylabel("Autocorrelation")
plt.title("")

_ = fig.set_size_inches(18,9)

# %%
import statsmodels.formula.api as smf

spy['lag'] = spy.ret.shift()
spy = spy.dropna()

trace = go.Scatter(
  x=spy.lag,
  y=spy.ret,
  text=spy.date,
  mode="markers",
  hovertemplate="%{text}<extra></extra>",
  showlegend=False,
  marker=dict(size=15)
)
fig = go.Figure(trace)

result = smf.ols("ret ~ lag", data=spy).fit()
predict = result.params['Intercept'] + result.params['lag']*spy.lag

trace = go.Scatter(
  x=spy.lag,
  y=predict,
  mode="lines",
  name="regression line",
)

fig.add_trace(trace)

fig.update_layout(
    template="plotly_dark",
    xaxis_title="Lagged Return",
    yaxis_title="Return",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat=".0%",
    width=1000,
    height=520,
)

fig.show()
# Out:
# <div>                            <div id="a28c1985-8ea4-4a3e-87bb-dd2bb9f1db2b" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a28c1985-8ea4-4a3e-87bb-dd2bb9f1db2b")) {                    Plotly.newPlot(                        "a28c1985-8ea4-4a3e-87bb-dd2bb9f1db2b",                        [{"hovertemplate":"%{text}<extra></extra>","marker":{"size":15},"mode":"markers","showlegend":false,"text":["1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"x":[0.003973445447384316,0.38048915188301935,0.22497490534788933,0.3347501285158707,0.2869255763047669,0.20389333274058763,-0.0974148791818914,-0.11758552586949056,-0.2158461757326453,0.2818152892535619,0.10697950162257253,0.04828287938446474,0.15845205362636383,0.05146260786492429,-0.36795003888133326,0.2635177400859683,0.15056146183782215,0.018949427315235745,0.15990375464002082,0.3230777034727863,0.13463792709011457,0.01234277369120762,0.11997918237501937,0.21705407874612925,-0.04568998560465498,0.31223833770909604,0.18331641126806586,0.28728768193342535],"y":[0.38048915188301935,0.22497490534788933,0.3347501285158707,0.2869255763047669,0.20389333274058763,-0.0974148791818914,-0.11758552586949056,-0.2158461757326453,0.2818152892535619,0.10697950162257253,0.04828287938446474,0.15845205362636383,0.05146260786492429,-0.36795003888133326,0.2635177400859683,0.15056146183782215,0.018949427315235745,0.15990375464002082,0.3230777034727863,0.13463792709011457,0.01234277369120762,0.11997918237501937,0.21705407874612925,-0.04568998560465498,0.31223833770909604,0.18331641126806586,0.28728768193342535,-0.21526872696348398],"type":"scatter"},{"mode":"lines","name":"regression line","x":[0.003973445447384316,0.38048915188301935,0.22497490534788933,0.3347501285158707,0.2869255763047669,0.20389333274058763,-0.0974148791818914,-0.11758552586949056,-0.2158461757326453,0.2818152892535619,0.10697950162257253,0.04828287938446474,0.15845205362636383,0.05146260786492429,-0.36795003888133326,0.2635177400859683,0.15056146183782215,0.018949427315235745,0.15990375464002082,0.3230777034727863,0.13463792709011457,0.01234277369120762,0.11997918237501937,0.21705407874612925,-0.04568998560465498,0.31223833770909604,0.18331641126806586,0.28728768193342535],"y":[0.11279981555225035,0.1176630193641004,0.11565434492205312,0.11707223871673997,0.11645452067566583,0.11538204822231067,0.11149024976684938,0.11122971889341719,0.10996055120983465,0.11638851448510784,0.11413027650373911,0.11337213114052598,0.11479511334010964,0.11341320158566945,0.10799592642946505,0.11615217717078502,0.11469319579614565,0.1129932503834169,0.1148138639998633,0.1169214737393624,0.11448752205250219,0.11290791661768344,0.11429818476336158,0.11555203685504752,0.11215834593206303,0.11678146883651508,0.1151162697667752,0.11645919775405456],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type ...
