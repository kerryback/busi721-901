# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'':
  os.chdir(r'')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# C:\Users\kerry\AppData\Local\Temp\ipykernel_29260\3609341226.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)
# {"C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap_external.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\codecs.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\aliases.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\__init__.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\utf_8.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\cp1252.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\abc.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\io.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\stat.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_collections_abc.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\genericpath.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\os.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_sitebuiltins.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\types.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\warnings.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\__init__.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_abc.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\keyword.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\operator.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\reprlib.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\__init__.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\functools.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\contextlib.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\util.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\machinery.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib\\pywin32_bootstrap.py": 1661087294.7744937, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\runpy.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\enum.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_constants.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_parse.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_compile.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\copyreg.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\re.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\abc.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\typing.py": 1647454514.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\ipykernel\\_version.py": 1656533197.6467216, "C:\\Users\\kerry\\AppData\\Local ...

# %%
import numpy as np
import plotly.graph_objects as go

mn = 0.125
sd = 0.174
nsims = 1000

r = np.random.normal(loc=mn, scale=sd, size=30*nsims)
r = r.reshape((30,1000))
comp_ret = np.prod(1+r, axis=0)

trace = go.Box(
  y=comp_ret,
  name="",
  hovertemplate="%{text}<extra></extra>",
)
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    yaxis_title="Accumulation from $1",
    xaxis_title="",
    yaxis_tickprefix="$",
    yaxis_tickformat=".0f",
    xaxis_tickformat="",
)
fig.update_xaxes(title_font_size=24)
fig.update_yaxes(title_font_size=24)
fig.update_layout(font_size=20)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6c6e77c7-f416-4c61-9b83-1fea41fe6110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c6e77c7-f416-4c61-9b83-1fea41fe6110")) {                    Plotly.newPlot(                        "6c6e77c7-f416-4c61-9b83-1fea41fe6110",                        [{"hovertemplate":"%{text}<extra></extra>","name":"","y":[11.423236333105272,46.85772667532844,23.764918300262256,20.850723749264272,11.648769756555176,8.208604893543916,52.22423598982308,19.382227627594677,33.70702870837799,16.976246491371146,13.111322983919605,18.368536308345828,24.84870758677906,12.067427929472583,5.131398690106057,30.8803931312059,69.04092240588301,30.342194747638295,25.244974829733778,54.2845538506303,5.3600053714281,41.1332826704879,26.229052058017228,109.22685659841146,30.937984673216437,23.374677106973618,11.608968180589674,43.483701938241026,2.9261971795535198,53.99301751150636,60.8149122715954,9.009234377837998,22.058985549028293,17.550944289553716,33.06822672126896,70.14122161930699,19.647762768974093,11.37226308259802,53.32217440033239,34.73312239993436,6.179651031565352,42.83477192556873,23.675002150750238,139.57679680293595,8.130568061135063,25.913898890692607,33.84410861715828,41.65893524674468,9.665545719198358,74.40963807515595,5.100297956099624,22.777431669491367,26.655588540563013,59.51789195698846,11.68144004751734,17.07862609540467,33.92070074701091,34.60349442432064,56.64916588331054,138.69051364898917,4.73974152595208,27.955213046376755,18.07667240886043,35.86212396841468,78.66259976495571,30.7469604349116,15.680756642671101,38.35047905585668,8.781092575256508,40.55022599300316,10.541110170046165,72.88566338025115,30.244637866166855,69.7722861249944,12.566393441526937,27.166439741436868,11.663448666611236,45.070949955226425,18.58133916870048,4.493412097492888,51.888919791508656,22.857503364050093,29.784789451406983,24.036860161445578,12.334411195276966,11.437030628864214,33.892848987128026,58.50414159807864,75.42901026330951,13.617672025319113,10.055066988776137,14.093351005834592,17.146883137324473,101.3625688632858,91.32503132411671,21.04825531215302,13.729264000296922,16.695102699038667,8.892779963624704,21.020356595813666,29.89819637514133,89.83328228093804,16.756166447231944,7.871730880099715,71.05700387972105,12.44126970065143,11.952257669818477,28.55633949549523,78.60115913787881,45.30371847719733,53.07162111821277,36.31845333684944,58.32159747650632,8.14531934997685,19.804131299320865,26.54003296819307,44.48015885643526,24.234784439465376,24.383352011880664,13.088559290587197,6.280062394787593,4.408647666812507,58.070455305331556,14.83939353504253,21.216966959864408,21.322621106754305,15.756923125207958,11.711504693926246,55.00820004787704,28.99724815525686,7.640076912788991,74.00966047187501,9.891336437840422,26.644718511087856,38.49782091498621,17.62686291590206,50.318932588183955,62.00852924448501,31.774875371484082,9.60248626537537,129.51413996580862,25.720937493632086,11.028824190206231,10.67774312015886,92.71587538637102,28.90251705552632,4.416675464622402,12.567203756714573,159.48279779486023,9.399431863925562,7.527355607297988,24.260576740814408,60.56540073154397,5.419564340083629,13.325977281693039,18.1475171553045,50.21982719832164,25.54080954127216,5.945842563547332,26.30783303552868,61.83834467191226,24.220331430581833,9.177010178314097,15.139428936678335,33.2555379865331,20.73221178281913,11.252949224003062,23.861082003614566,20.524022459731764,4.864334604668135,38.016359167560005,86.18037220281492,13.911564920035463,13.279914786702676,45.312193571058515,28.537957402967983,30.531984525663674,157.34073265072894,6.201386910064051,46.513187443737316,13.49566442915103,16.71423759600484,120.42440239153206,3.7132435535140713,55.926817370499656,20.936834 ...

# %%
import pandas as pd
comp_ret = pd.Series(comp_ret)
table = comp_ret.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
print(table.iloc[1:].round(2))
# Out:
# mean     34.87
# std      34.34
# min       0.79
# 10%       7.73
# 25%      12.61
# 50%      24.19
# 75%      44.27
# 90%      74.43
# max     276.22
# dtype: float64
