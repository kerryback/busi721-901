# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'':
  os.chdir(r'')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# C:\Users\kerry\AppData\Local\Temp\ipykernel_19536\1140549349.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)
# {"C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap_external.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\codecs.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\aliases.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\__init__.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\utf_8.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\cp1252.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\abc.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\io.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\stat.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_collections_abc.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\genericpath.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\os.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_sitebuiltins.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_distutils_hack\\__init__.py": 1703948569.2002509, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\types.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\warnings.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\__init__.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_abc.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\keyword.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\operator.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\reprlib.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\__init__.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\functools.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\contextlib.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\util.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\machinery.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib\\pywin32_bootstrap.py": 1665545610.7738168, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\runpy.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\enum.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_constants.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_parse.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_compile.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\copyreg.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\re.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\abc.py": 1680677242.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\typing.py": 1680677242.0, "C:\\Users\\kerry\\AppData\ ...

# %%
import yfinance as yf
import plotly.graph_objects as go
import numpy as np

spy = yf.download('SPY', start=1990)['Adj Close']
spy = spy.resample('Y').last()
spy = spy.pct_change().dropna()
spy.index = spy.index.to_period('Y').astype(str)
spy = spy.reset_index()
spy.columns = ['date', 'ret']

trace = go.Scatter(
    x=spy.date,
    y=spy.ret,
        hovertemplate="%{x}<br>%{y:.1%}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="",
    yaxis_tickformat=".0%",
    width=1000,
    height=460,
  )
fig.update_xaxes(title_font_size=24)
fig.update_yaxes(title_font_size=24)
fig.update_layout(font_size=20)

fig.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a63dad77-7d52-4c7c-9d5d-83a63a384214" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a63dad77-7d52-4c7c-9d5d-83a63a384214")) {                    Plotly.newPlot(                        "a63dad77-7d52-4c7c-9d5d-83a63a384214",                        [{"hovertemplate":"%{x}\u003cbr\u003e%{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[0.00397381931069507,0.3804893522853978,0.22497497772966968,0.33475091999466167,0.2869247329845439,0.20389334753175503,-0.09741490990886958,-0.11758566735167852,-0.21584581026177607,0.2818151351714908,0.10697896776429605,0.04828309578145484,0.1584523491392098,0.05146228058014768,-0.36794986927701123,0.26351746671827314,0.15056162866078227,0.018949782839418727,0.15990303723392696,0.3230784201656196,0.13463767044279606,0.012342840930663623,0.11997889647561322,0.21705416932069777,-0.045690083569474904,0.31223861492992966,0.183316223284671,0.28728768695255646,-0.18175356934642606,0.26175781200316894,0.03256824191757057],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333 ...

# %%
compound = (1+spy.ret).cumprod()

trace = go.Scatter(
    x=spy.date,
    y=compound,
        hovertemplate="%{x}<br>$%{y:.2f}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation from $1",
    yaxis_tickformat=".0f",
    width=1000,
    height=460,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="right", 
        x=0.99
    )
  )
fig.update_xaxes(title_font_size=24)
fig.update_yaxes(title_font_size=24)
fig.update_layout(font_size=20)

fig.show()
# Out:
# <div>                            <div id="7ea026a4-3335-4946-8fd2-2d3922b53df9" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ea026a4-3335-4946-8fd2-2d3922b53df9")) {                    Plotly.newPlot(                        "7ea026a4-3335-4946-8fd2-2d3922b53df9",                        [{"hovertemplate":"%{x}\u003cbr\u003e$%{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[1.003973819310695,1.3859751675317185,1.697784899981042,2.2661199572027404,2.9163258208340825,3.510945254937237,3.168926839232553,2.796306462052748,2.192735428010732,2.8106814590508935,3.1113652602544035,3.261591607126358,3.7783984592082605,3.9728434608596337,2.511036228778303,3.172738134623767,3.6504307554868936,3.7196056255737053,4.314381862415342,5.708265538515694,6.47681311289034,6.556755386880382,7.343427662658822,8.937349253943866,8.529001019641587,11.192084484750435,13.243775143177848,17.048548670581173,13.949914097526777,17.601413089327547,18.17466016891186],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"], ...

# %%
r1 = np.cumprod([1] + 51*[1.1])
r2 = np.cumprod([1] + 30*[1.02] + 21*[1.1])
years = np.arange(1970, 2022)

trace1 = go.Scatter(
  x=years,
  y=r1,
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=r2,
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>accum = %{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickprefix="$", 
    yaxis_tickformat=",.0f",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    )
)

fig.show()
# Out:
# <div>                            <div id="eecaec3b-5182-4e08-87c8-e9d2fd79f337" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eecaec3b-5182-4e08-87c8-e9d2fd79f337")) {                    Plotly.newPlot(                        "eecaec3b-5182-4e08-87c8-e9d2fd79f337",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.1,1.2100000000000002,1.3310000000000004,1.4641000000000006,1.6105100000000008,1.771561000000001,1.9487171000000014,2.1435888100000016,2.357947691000002,2.5937424601000023,2.853116706110003,3.1384283767210035,3.4522712143931042,3.797498335832415,4.177248169415656,4.594972986357222,5.054470284992944,5.559917313492239,6.115909044841463,6.72749994932561,7.400249944258172,8.140274938683989,8.954302432552389,9.849732675807628,10.834705943388391,11.91817653772723,13.109994191499954,14.420993610649951,15.863092971714948,17.449402268886445,19.19434249577509,21.1137767453526,23.22515441988786,25.54766986187665,28.102436848064315,30.91268053287075,34.003948586157826,37.40434344477361,41.14477778925097,45.25925556817607,49.785181124993684,54.76369923749306,60.24006916124237,66.26407607736661,72.89048368510328,80.17953205361361,88.19748525897498,97.01723378487249,106.71895716335975,117.39085287969573,129.1299381676653],"type":"scatter","hovertemplate":"year %{x}\u003cbr\u003eaccum = %{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.02,1.0404,1.061208,1.08243216,1.1040808032,1.126162419264,1.14868566764928,1.1716593810022657,1.195092568622311,1.2189944199947573,1.2433743083946525,1.2682417945625455,1.2936066304537963,1.3194787630628724,1.3458683383241299,1.3727857050906125,1.4002414191924248,1.4282462475762734,1.4568111725277988,1.485947395978355,1.515666343897922,1.5459796707758806,1.5768992641913981,1.6084372494752261,1.6406059944647307,1.6734181143540252,1.7068864766411058,1.741024206173928,1.7758446902974065,1.8113615841033548,1.9924977425136905,2.1917475167650595,2.4109222684415657,2.6520144952857225,2.917215944814295,3.2089375392957247,3.5298312932252975,3.8828144225478276,4.271095864802611,4.698205451282872,5.16802599641116,5.684828596052276,6.253311455657505,6.878642601223255,7.566506861345581,8.32315754748014,9.155473302228154,10.07102063245097,11.078122695696068,12.185934965265677,13.404528461792246],"type":"scatter","hovertemplate":"year %{x}\u003cbr\u003eaccum = %{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinew ...

# %%
trace1 = go.Scatter(
  x=years,
  y=np.log10(r1),
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=np.log10(r2),
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>log = %{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Log of Accumulation",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=",.1f",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    )
)

fig.show()
# Out:
# <div>                            <div id="c3789d3e-4336-4524-8db4-bc20bbf5f2ec" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3789d3e-4336-4524-8db4-bc20bbf5f2ec")) {                    Plotly.newPlot(                        "c3789d3e-4336-4524-8db4-bc20bbf5f2ec",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.0,0.04139268515822508,0.08278537031645015,0.12417805547467525,0.16557074063290034,0.20696342579112542,0.2483561109493505,0.2897487961075756,0.3311414812658006,0.3725341664240257,0.4139268515822508,0.45531953674047587,0.49671222189870096,0.538104907056926,0.5794975922151511,0.6208902773733762,0.6622829625316012,0.7036756476898263,0.7450683328480513,0.7864610180062764,0.8278537031645015,0.8692463883227265,0.9106390734809516,0.9520317586391767,0.9934244437974017,1.0348171289556267,1.0762098141138519,1.1176024992720768,1.158995184430302,1.200387869588527,1.2417805547467522,1.2831732399049771,1.3245659250632023,1.3659586102214274,1.4073512953796523,1.4487439805378775,1.4901366656961026,1.5315293508543275,1.5729220360125526,1.6143147211707778,1.6557074063290027,1.6971000914872278,1.738492776645453,1.7798854618036781,1.821278146961903,1.8626708321201282,1.9040635172783533,1.9454562024365782,1.9868488875948034,2.0282415727530285,2.0696342579112534,2.111026943069479],"type":"scatter","hovertemplate":"year %{x}\u003cbr\u003elog = %{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.0,0.00860017176191757,0.017200343523835118,0.025800515285752654,0.034400687047670235,0.04300085880958781,0.05160103057150539,0.060201202333422944,0.06880137409534054,0.0774015458572581,0.08600171761917567,0.09460188938109323,0.1032020611430108,0.11180223290492833,0.12040240466684593,0.1290025764287635,0.13760274819068108,0.14620291995259865,0.15480309171451626,0.16340326347643377,0.17200343523835138,0.18060360700026898,0.18920377876218655,0.1978039505241041,0.20640412228602167,0.21500429404793922,0.22360446580985677,0.23220463757177437,0.24080480933369194,0.2494049810956095,0.25800515285752706,0.29939783801575215,0.34079052317397723,0.38218320833220226,0.42357589349042735,0.46496857864865243,0.5063612638068775,0.5477539489651025,0.5891466341233277,0.6305393192815527,0.6719320044397779,0.7133246895980029,0.754717374756228,0.796110059914453,0.8375027450726781,0.8788954302309032,0.9202881153891282,0.9616808005473533,1.0030734857055783,1.0444661708638034,1.0858588560220286,1.1272515411802537],"type":"scatter","hovertemplate":"year %{x}\u003cbr\u003elog = %{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0," ...

# %%
trace1 = go.Scatter(
  x=years,
  y=r1,
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=r2,
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>$%{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_type="log",
    yaxis_tickformat=",.0f",
    yaxis_tickprefix="$",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    ),
    yaxis = dict(
        tickmode = 'array',
        tickvals = [1, 2, 5, 10, 20, 50, 100],
    )
)

fig.show()
# Out:
# <div>                            <div id="1b8a35fa-ff81-41ca-822a-6a24b3d09ce4" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b8a35fa-ff81-41ca-822a-6a24b3d09ce4")) {                    Plotly.newPlot(                        "1b8a35fa-ff81-41ca-822a-6a24b3d09ce4",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.1,1.2100000000000002,1.3310000000000004,1.4641000000000006,1.6105100000000008,1.771561000000001,1.9487171000000014,2.1435888100000016,2.357947691000002,2.5937424601000023,2.853116706110003,3.1384283767210035,3.4522712143931042,3.797498335832415,4.177248169415656,4.594972986357222,5.054470284992944,5.559917313492239,6.115909044841463,6.72749994932561,7.400249944258172,8.140274938683989,8.954302432552389,9.849732675807628,10.834705943388391,11.91817653772723,13.109994191499954,14.420993610649951,15.863092971714948,17.449402268886445,19.19434249577509,21.1137767453526,23.22515441988786,25.54766986187665,28.102436848064315,30.91268053287075,34.003948586157826,37.40434344477361,41.14477778925097,45.25925556817607,49.785181124993684,54.76369923749306,60.24006916124237,66.26407607736661,72.89048368510328,80.17953205361361,88.19748525897498,97.01723378487249,106.71895716335975,117.39085287969573,129.1299381676653],"type":"scatter","hovertemplate":"year %{x}\u003cbr\u003e$%{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.02,1.0404,1.061208,1.08243216,1.1040808032,1.126162419264,1.14868566764928,1.1716593810022657,1.195092568622311,1.2189944199947573,1.2433743083946525,1.2682417945625455,1.2936066304537963,1.3194787630628724,1.3458683383241299,1.3727857050906125,1.4002414191924248,1.4282462475762734,1.4568111725277988,1.485947395978355,1.515666343897922,1.5459796707758806,1.5768992641913981,1.6084372494752261,1.6406059944647307,1.6734181143540252,1.7068864766411058,1.741024206173928,1.7758446902974065,1.8113615841033548,1.9924977425136905,2.1917475167650595,2.4109222684415657,2.6520144952857225,2.917215944814295,3.2089375392957247,3.5298312932252975,3.8828144225478276,4.271095864802611,4.698205451282872,5.16802599641116,5.684828596052276,6.253311455657505,6.878642601223255,7.566506861345581,8.32315754748014,9.155473302228154,10.07102063245097,11.078122695696068,12.185934965265677,13.404528461792246],"type":"scatter","hovertemplate":"year %{x}\u003cbr\u003e$%{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks ...

# %%
trace = go.Scatter(
    x=spy.date,
    y=compound,
        hovertemplate="%{x}<br>$%{y:.2f}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation from $1",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0f",
    yaxis_type="log",
    width=1000,
    height=460,
    yaxis = dict(
        tickmode = 'array',
        tickvals = [2, 5, 10, 16],
    )
  )

fig.show()
# Out:
# <div>                            <div id="01effba5-0525-4c45-9404-9028a23087fd" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01effba5-0525-4c45-9404-9028a23087fd")) {                    Plotly.newPlot(                        "01effba5-0525-4c45-9404-9028a23087fd",                        [{"hovertemplate":"%{x}\u003cbr\u003e$%{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[1.003973819310695,1.3859751675317185,1.697784899981042,2.2661199572027404,2.9163258208340825,3.510945254937237,3.168926839232553,2.796306462052748,2.192735428010732,2.8106814590508935,3.1113652602544035,3.261591607126358,3.7783984592082605,3.9728434608596337,2.511036228778303,3.172738134623767,3.6504307554868936,3.7196056255737053,4.314381862415342,5.708265538515694,6.47681311289034,6.556755386880382,7.343427662658822,8.937349253943866,8.529001019641587,11.192084484750435,13.243775143177848,17.048548670581173,13.949914097526777,17.601413089327547,18.17466016891186],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"], ...

# %%
trace = go.Box(
    x=spy.ret,
    text=spy.date,
    hovertemplate="%{text}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    yaxis_title="",
    xaxis_title="Annual Return",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat="",
    width=1000,
    height=500,
)

fig.show()
# Out:
# <div>                            <div id="b0f84ba7-706c-40c4-a358-e1a3332ffc67" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0f84ba7-706c-40c4-a358-e1a3332ffc67")) {                    Plotly.newPlot(                        "b0f84ba7-706c-40c4-a358-e1a3332ffc67",                        [{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","name":"","text":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"x":[0.00397381931069507,0.3804893522853978,0.22497497772966968,0.33475091999466167,0.2869247329845439,0.20389334753175503,-0.09741490990886958,-0.11758566735167852,-0.21584581026177607,0.2818151351714908,0.10697896776429605,0.04828309578145484,0.1584523491392098,0.05146228058014768,-0.36794986927701123,0.26351746671827314,0.15056162866078227,0.018949782839418727,0.15990303723392696,0.3230784201656196,0.13463767044279606,0.012342840930663623,0.11997889647561322,0.21705416932069777,-0.045690083569474904,0.31223861492992966,0.183316223284671,0.28728768695255646,-0.18175356934642606,0.26175781200316894,0.03256824191757057],"type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[ ...

# %%
from scipy.stats import norm
from scipy.stats import gaussian_kde as kde

density = kde(spy.ret)
grid = np.linspace(np.min(spy.ret), np.max(spy.ret), 100)

trace1 = go.Scatter(
  x=grid,
  y=density(grid),
  mode="lines",
  name="actual"
)

trace2 = go.Scatter(
  x=grid, 
  y=norm.pdf(grid, np.mean(spy.ret), scale=np.std(spy.ret)), 
  mode="lines", 
  name="normal"
)
fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="Annual Return",
    yaxis_title="",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat="",
    width=1000,
    height=360,
     legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.01
    ),
)

fig.show()
# Out:
# <div>                            <div id="025e4f25-f2dc-425d-a61a-b694cb2e7927" class="plotly-graph-div" style="height:360px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("025e4f25-f2dc-425d-a61a-b694cb2e7927")) {                    Plotly.newPlot(                        "025e4f25-f2dc-425d-a61a-b694cb2e7927",                        [{"mode":"lines","name":"actual","x":[-0.36794986927701123,-0.3603898771400172,-0.35282988500302315,-0.34526989286602916,-0.3377099007290351,-0.3301499085920411,-0.32258991645504703,-0.315029924318053,-0.307469932181059,-0.29990994004406496,-0.2923499479070709,-0.28478995577007693,-0.27722996363308283,-0.26966997149608884,-0.2621099793590948,-0.25454998722210076,-0.24698999508510674,-0.2394300029481127,-0.2318700108111187,-0.22431001867412464,-0.21675002653713063,-0.2091900344001366,-0.20163004226314257,-0.19407005012614853,-0.1865100579891545,-0.17895006585216047,-0.17139007371516643,-0.16383008157817242,-0.15627008944117837,-0.14871009730418436,-0.14115010516719032,-0.1335901130301963,-0.12603012089320226,-0.11847012875620822,-0.11091013661921417,-0.10335014448222019,-0.09579015234522614,-0.0882301602082321,-0.08067016807123806,-0.07311017593424407,-0.06555018379725003,-0.057990191660255985,-0.05043019952326194,-0.0428702073862679,-0.03531021524927391,-0.02775022311227987,-0.020190230975285828,-0.012630238838291785,-0.005070246701297743,0.0024897454356962445,0.010049737572690287,0.01760972970968433,0.025169721846678372,0.03272971398367236,0.0402897061206664,0.047849698257660445,0.05540969039465449,0.06296968253164853,0.07052967466864252,0.07808966680563656,0.0856496589426306,0.09320965107962464,0.10076964321661863,0.10832963535361267,0.11588962749060672,0.12344961962760076,0.1310096117645948,0.1385696039015888,0.1461295960385829,0.15368958817557687,0.16124958031257086,0.16880957244956496,0.17636956458655895,0.18392955672355304,0.19148954886054703,0.19904954099754102,0.20660953313453512,0.2141695252715291,0.2217295174085231,0.2292895095455172,0.23684950168251118,0.24440949381950527,0.25196948595649926,0.25952947809349325,0.26708947023048735,0.27464946236748133,0.28220945450447543,0.2897694466414694,0.2973294387784634,0.3048894309154575,0.3124494230524515,0.3200094151894456,0.3275694073264396,0.33512939946343356,0.34268939160042766,0.35024938373742165,0.35780937587441575,0.36536936801140973,0.3729293601484037,0.3804893522853978],"y":[0.19906219598290448,0.2081844074196434,0.21748502556006774,0.2270476113582729,0.2369633599131125,0.24732754261968637,0.25823566137603743,0.2697795159057555,0.2820433969176239,0.2951006166742672,0.3090105743330291,0.32381652680285283,0.3395441983360315,0.3562013158951279,0.373778105333855,0.392248728806619,0.4115735899127402,0.43170238312985687,0.45257772102639016,0.4741391390027434,0.4963272547078421,0.519087848922679,0.5423756369829631,0.5661575144219134,0.5904150865203094,0.6151463273968616,0.640366258286813,0.6661065845697658,0.6924142845539702,0.7193491975352354,0.7469807117280358,0.7753837018540995,0.8046339091042033,0.8348029906532685,0.8659534899284592,0.898133990746461,0.9313747170189752,0.9656838242920202,1.0010445999214963,1.0374137459572366,1.0747208644215835,1.112869201104991,1.1517376345538384,1.191183825568817,1.231048373702337,1.2711597655443883,1.311339849439164,1.351409536540375,1.3911944117253459,1.4305299415379824,1.469265990241347,1.5072703978832205,1.5444314331332434,1.5806590043187096,1.615884589339655,1.650059923189434,1.6831545548013687,1.7151524475275053,1.7460478453571044,1.7758406570153766,1.8045316210220053,1.832117507069318,1.8585865848158936,1.8839145539199922,1.9080610834137663,1.9309670594098214,1.9525525926574856,1.9727157960636745,1.9913323103485323,2.0082555355172853,2.023317517232383,2.036330439344664,2.0470886843017633,2.055371438382899,2. ...

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt
plt.style.use('classic')
plt.rcParams.update({'font.size': 26})
fig = plot_acf(spy.ret)
plt.xlabel("Year")
plt.ylabel("Autocorrelation")
plt.title("")

_ = fig.set_size_inches(18,9)

# %%
import statsmodels.formula.api as smf

spy['lag'] = spy.ret.shift()
spy = spy.dropna()

trace = go.Scatter(
  x=spy.lag,
  y=spy.ret,
  text=spy.date,
  mode="markers",
  hovertemplate="%{text}<extra></extra>",
  showlegend=False,
  marker=dict(size=15)
)
fig = go.Figure(trace)

result = smf.ols("ret ~ lag", data=spy).fit()
predict = result.params['Intercept'] + result.params['lag']*spy.lag

trace = go.Scatter(
  x=spy.lag,
  y=predict,
  mode="lines",
  name="regression line",
)

fig.add_trace(trace)

fig.update_layout(
    template="plotly_dark",
    xaxis_title="Lagged Return",
    yaxis_title="Return",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat=".0%",
    width=1000,
    height=520,
)

fig.show()
# Out:
# <div>                            <div id="88fb265c-12b6-4288-88e8-6d9083138554" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88fb265c-12b6-4288-88e8-6d9083138554")) {                    Plotly.newPlot(                        "88fb265c-12b6-4288-88e8-6d9083138554",                        [{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"size":15},"mode":"markers","showlegend":false,"text":["1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"x":[0.00397381931069507,0.3804893522853978,0.22497497772966968,0.33475091999466167,0.2869247329845439,0.20389334753175503,-0.09741490990886958,-0.11758566735167852,-0.21584581026177607,0.2818151351714908,0.10697896776429605,0.04828309578145484,0.1584523491392098,0.05146228058014768,-0.36794986927701123,0.26351746671827314,0.15056162866078227,0.018949782839418727,0.15990303723392696,0.3230784201656196,0.13463767044279606,0.012342840930663623,0.11997889647561322,0.21705416932069777,-0.045690083569474904,0.31223861492992966,0.183316223284671,0.28728768695255646,-0.18175356934642606,0.26175781200316894],"y":[0.3804893522853978,0.22497497772966968,0.33475091999466167,0.2869247329845439,0.20389334753175503,-0.09741490990886958,-0.11758566735167852,-0.21584581026177607,0.2818151351714908,0.10697896776429605,0.04828309578145484,0.1584523491392098,0.05146228058014768,-0.36794986927701123,0.26351746671827314,0.15056162866078227,0.018949782839418727,0.15990303723392696,0.3230784201656196,0.13463767044279606,0.012342840930663623,0.11997889647561322,0.21705416932069777,-0.045690083569474904,0.31223861492992966,0.183316223284671,0.28728768695255646,-0.18175356934642606,0.26175781200316894,0.03256824191757057],"type":"scatter"},{"mode":"lines","name":"regression line","x":[0.00397381931069507,0.3804893522853978,0.22497497772966968,0.33475091999466167,0.2869247329845439,0.20389334753175503,-0.09741490990886958,-0.11758566735167852,-0.21584581026177607,0.2818151351714908,0.10697896776429605,0.04828309578145484,0.1584523491392098,0.05146228058014768,-0.36794986927701123,0.26351746671827314,0.15056162866078227,0.018949782839418727,0.15990303723392696,0.3230784201656196,0.13463767044279606,0.012342840930663623,0.11997889647561322,0.21705416932069777,-0.045690083569474904,0.31223861492992966,0.183316223284671,0.28728768695255646,-0.18175356934642606,0.26175781200316894],"y":[0.12217769244030922,0.10699387923586424,0.11326533687057203,0.10883838165699904,0.11076707735809052,0.11411549976409555,0.12626641492499183,0.1270798448804151,0.1310424002724903,0.11097313307677571,0.11802378431105102,0.12039082385658646,0.11594800751208863,0.12026261626912152,0.13717632946653602,0.11171102661778186,0.11626621809120166,0.12157375392287229,0.11588950533855526,0.10930910076819436,0.11690838657000792,0.12184019332047848,0.11749953372392584,0.1135847608113583,0.12418049805732706,0.10974623964682421,0.11494531735059435,0.11075244044468466,0.12966755601655788,0.11178198854672905],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgr ...
