# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'':
  os.chdir(r'')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# C:\Users\kerry\AppData\Local\Temp\ipykernel_15820\1140549349.py:20: DeprecationWarning:
#
# `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
# {"C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_bootstrap_external.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\codecs.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\aliases.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\utf_8.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\encodings\\cp1252.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\io.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\stat.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_collections_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\genericpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\os.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\_sitebuiltins.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_distutils_hack\\__init__.py": 1665541945.6758869, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\types.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\warnings.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\_abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\keyword.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\operator.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\reprlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\__init__.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\functools.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\contextlib.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\util.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\importlib\\machinery.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib\\pywin32_bootstrap.py": 1665545610.7738168, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\runpy.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\enum.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_constants.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_parse.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\sre_compile.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\copyreg.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\re.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\collections\\abc.py": 1665532704.0, "C:\\Users\\kerry\\AppData\\Local\\Programs\\Python\\Python310\\lib\\typing.py": 1665532704.0, "C:\\Users\\kerry\\AppData\ ...

# %%
from pandas_datareader import DataReader as pdr
import plotly.graph_objects as go
import numpy as np

spy = pdr('SPY', 'yahoo', start=1990)['Adj Close']
spy = spy.resample('Y').last()
spy = spy.pct_change().dropna()
spy.index = spy.index.to_period('Y').astype(str)
spy = spy.reset_index()
spy.columns = ['date', 'ret']

trace = go.Scatter(
    x=spy.date,
    y=spy.ret,
        hovertemplate="%{x}<br>%{y:.1%}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="",
    yaxis_tickformat=".0%",
    width=1000,
    height=460,
  )
fig.update_xaxes(title_font_size=24)
fig.update_yaxes(title_font_size=24)
fig.update_layout(font_size=20)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1d957751-cfbd-46ab-96ab-1113016e5a91" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d957751-cfbd-46ab-96ab-1113016e5a91")) {                    Plotly.newPlot(                        "1d957751-cfbd-46ab-96ab-1113016e5a91",                        [{"hovertemplate":"%{x}<br>%{y:.1%}<extra></extra>","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"y":[0.0039723370704296546,0.38049016642955147,0.2249746729824058,0.33475159772983054,0.2869247896929432,0.20389352272320327,-0.09741525832622344,-0.11758520702967334,-0.21584635248585826,0.28181532485753036,0.10697970929015432,0.04828251893898239,0.15845268855114858,0.051462446135831286,-0.36795012702674845,0.26351785040919995,0.15056136137730336,0.018949806757595278,0.15990309927699076,0.3230784720148334,0.13463748657279484,0.01234294477882103,0.1199788240950701,0.21705396060180515,-0.04568981095604985,0.31223868279661926,0.18331627596092637,0.28728757422649687,-0.21697261993807615],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6 ...

# %%
compound = (1+spy.ret).cumprod()

trace = go.Scatter(
    x=spy.date,
    y=compound,
        hovertemplate="%{x}<br>$%{y:.2f}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation from $1",
    yaxis_tickformat=".0f",
    width=1000,
    height=460,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="right", 
        x=0.99
    )
  )
fig.update_xaxes(title_font_size=24)
fig.update_yaxes(title_font_size=24)
fig.update_layout(font_size=20)

fig.show()
# Out:
# <div>                            <div id="af495968-40db-446f-9baa-f1f279ada101" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af495968-40db-446f-9baa-f1f279ada101")) {                    Plotly.newPlot(                        "af495968-40db-446f-9baa-f1f279ada101",                        [{"hovertemplate":"%{x}<br>$%{y:.2f}<extra></extra>","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"y":[1.0039723370704297,1.3859739386930232,1.697782972312623,2.266118534892774,2.916324118936164,3.5109437169487006,3.168924227793312,2.7963056164068876,2.1927332486697413,2.8106790814695124,3.111364712513039,3.261589238171031,3.7783968219087236,3.9728423648359974,2.5110345120373445,3.17273692895274,3.6504285202679094,3.7196034353094007,4.314379552696716,5.708262706274011,6.476808849743964,6.5567517437193334,7.34342310781408,8.937342177739943,8.528996703189474,11.192079399370064,13.243769715121585,17.048540190193208,13.3494737590074],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...

# %%
r1 = np.cumprod([1] + 51*[1.1])
r2 = np.cumprod([1] + 30*[1.02] + 21*[1.1])
years = np.arange(1970, 2022)

trace1 = go.Scatter(
  x=years,
  y=r1,
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=r2,
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>accum = %{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickprefix="$", 
    yaxis_tickformat=",.0f",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    )
)

fig.show()
# Out:
# <div>                            <div id="dbfa1f22-900d-47aa-a978-ecaee3a4af34" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbfa1f22-900d-47aa-a978-ecaee3a4af34")) {                    Plotly.newPlot(                        "dbfa1f22-900d-47aa-a978-ecaee3a4af34",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.1,1.2100000000000002,1.3310000000000004,1.4641000000000006,1.6105100000000008,1.771561000000001,1.9487171000000014,2.1435888100000016,2.357947691000002,2.5937424601000023,2.853116706110003,3.1384283767210035,3.4522712143931042,3.797498335832415,4.177248169415656,4.594972986357222,5.054470284992944,5.559917313492239,6.115909044841463,6.72749994932561,7.400249944258172,8.140274938683989,8.954302432552389,9.849732675807628,10.834705943388391,11.91817653772723,13.109994191499954,14.420993610649951,15.863092971714948,17.449402268886445,19.19434249577509,21.1137767453526,23.22515441988786,25.54766986187665,28.102436848064315,30.91268053287075,34.003948586157826,37.40434344477361,41.14477778925097,45.25925556817607,49.785181124993684,54.76369923749306,60.24006916124237,66.26407607736661,72.89048368510328,80.17953205361361,88.19748525897498,97.01723378487249,106.71895716335975,117.39085287969573,129.1299381676653],"type":"scatter","hovertemplate":"year %{x}<br>accum = %{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.02,1.0404,1.061208,1.08243216,1.1040808032,1.126162419264,1.14868566764928,1.1716593810022657,1.195092568622311,1.2189944199947573,1.2433743083946525,1.2682417945625455,1.2936066304537963,1.3194787630628724,1.3458683383241299,1.3727857050906125,1.4002414191924248,1.4282462475762734,1.4568111725277988,1.485947395978355,1.515666343897922,1.5459796707758806,1.5768992641913981,1.6084372494752261,1.6406059944647307,1.6734181143540252,1.7068864766411058,1.741024206173928,1.7758446902974065,1.8113615841033548,1.9924977425136905,2.1917475167650595,2.4109222684415657,2.6520144952857225,2.917215944814295,3.2089375392957247,3.5298312932252975,3.8828144225478276,4.271095864802611,4.698205451282872,5.16802599641116,5.684828596052276,6.253311455657505,6.878642601223255,7.566506861345581,8.32315754748014,9.155473302228154,10.07102063245097,11.078122695696068,12.185934965265677,13.404528461792246],"type":"scatter","hovertemplate":"year %{x}<br>accum = %{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""}, ...

# %%
trace1 = go.Scatter(
  x=years,
  y=np.log10(r1),
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=np.log10(r2),
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>log = %{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Log of Accumulation",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=",.1f",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    )
)

fig.show()
# Out:
# <div>                            <div id="bd356293-0cf1-4336-bdcf-172ef66d8078" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd356293-0cf1-4336-bdcf-172ef66d8078")) {                    Plotly.newPlot(                        "bd356293-0cf1-4336-bdcf-172ef66d8078",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.0,0.04139268515822508,0.08278537031645015,0.12417805547467525,0.16557074063290034,0.20696342579112542,0.2483561109493505,0.2897487961075756,0.3311414812658006,0.3725341664240257,0.4139268515822508,0.45531953674047587,0.49671222189870096,0.538104907056926,0.5794975922151511,0.6208902773733762,0.6622829625316012,0.7036756476898263,0.7450683328480513,0.7864610180062764,0.8278537031645015,0.8692463883227265,0.9106390734809516,0.9520317586391767,0.9934244437974017,1.0348171289556267,1.0762098141138519,1.1176024992720768,1.158995184430302,1.200387869588527,1.2417805547467522,1.2831732399049771,1.3245659250632023,1.3659586102214274,1.4073512953796523,1.4487439805378775,1.4901366656961026,1.5315293508543275,1.5729220360125526,1.6143147211707778,1.6557074063290027,1.6971000914872278,1.738492776645453,1.7798854618036781,1.821278146961903,1.8626708321201282,1.9040635172783533,1.9454562024365782,1.9868488875948034,2.0282415727530285,2.0696342579112534,2.111026943069479],"type":"scatter","hovertemplate":"year %{x}<br>log = %{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[0.0,0.00860017176191757,0.017200343523835118,0.025800515285752654,0.034400687047670235,0.04300085880958781,0.05160103057150539,0.060201202333422944,0.06880137409534054,0.0774015458572581,0.08600171761917567,0.09460188938109323,0.1032020611430108,0.11180223290492833,0.12040240466684593,0.1290025764287635,0.13760274819068108,0.14620291995259865,0.15480309171451626,0.16340326347643377,0.17200343523835138,0.18060360700026898,0.18920377876218655,0.1978039505241041,0.20640412228602167,0.21500429404793922,0.22360446580985677,0.23220463757177437,0.24080480933369194,0.2494049810956095,0.25800515285752706,0.29939783801575215,0.34079052317397723,0.38218320833220226,0.42357589349042735,0.46496857864865243,0.5063612638068775,0.5477539489651025,0.5891466341233277,0.6305393192815527,0.6719320044397779,0.7133246895980029,0.754717374756228,0.796110059914453,0.8375027450726781,0.8788954302309032,0.9202881153891282,0.9616808005473533,1.0030734857055783,1.0444661708638034,1.0858588560220286,1.1272515411802537],"type":"scatter","hovertemplate":"year %{x}<br>log = %{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"c ...

# %%
trace1 = go.Scatter(
  x=years,
  y=r1,
  mode="lines",
  name="stock 1"
)

trace2 = go.Scatter(
  x=years,
  y=r2,
  mode="lines",
  name="stock 2"
)

fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
string = "year %{x}<br>log = %{y:.2f}"
fig.update_traces(hovertemplate=string)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation ($)",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=",.0f",
    width=1000,
    height=520,
    legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="left", 
        x=0.1
    ),
    yaxis = dict(
        tickmode = 'array',
        tickvals = [1, 2, 5, 10, 20, 50, 100],
    )
)

fig.show()
# Out:
# <div>                            <div id="7f450ef1-fbe4-4b2d-a2fa-f2587fdb11e4" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f450ef1-fbe4-4b2d-a2fa-f2587fdb11e4")) {                    Plotly.newPlot(                        "7f450ef1-fbe4-4b2d-a2fa-f2587fdb11e4",                        [{"mode":"lines","name":"stock 1","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.1,1.2100000000000002,1.3310000000000004,1.4641000000000006,1.6105100000000008,1.771561000000001,1.9487171000000014,2.1435888100000016,2.357947691000002,2.5937424601000023,2.853116706110003,3.1384283767210035,3.4522712143931042,3.797498335832415,4.177248169415656,4.594972986357222,5.054470284992944,5.559917313492239,6.115909044841463,6.72749994932561,7.400249944258172,8.140274938683989,8.954302432552389,9.849732675807628,10.834705943388391,11.91817653772723,13.109994191499954,14.420993610649951,15.863092971714948,17.449402268886445,19.19434249577509,21.1137767453526,23.22515441988786,25.54766986187665,28.102436848064315,30.91268053287075,34.003948586157826,37.40434344477361,41.14477778925097,45.25925556817607,49.785181124993684,54.76369923749306,60.24006916124237,66.26407607736661,72.89048368510328,80.17953205361361,88.19748525897498,97.01723378487249,106.71895716335975,117.39085287969573,129.1299381676653],"type":"scatter","hovertemplate":"year %{x}<br>log = %{y:.2f}"},{"mode":"lines","name":"stock 2","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[1.0,1.02,1.0404,1.061208,1.08243216,1.1040808032,1.126162419264,1.14868566764928,1.1716593810022657,1.195092568622311,1.2189944199947573,1.2433743083946525,1.2682417945625455,1.2936066304537963,1.3194787630628724,1.3458683383241299,1.3727857050906125,1.4002414191924248,1.4282462475762734,1.4568111725277988,1.485947395978355,1.515666343897922,1.5459796707758806,1.5768992641913981,1.6084372494752261,1.6406059944647307,1.6734181143540252,1.7068864766411058,1.741024206173928,1.7758446902974065,1.8113615841033548,1.9924977425136905,2.1917475167650595,2.4109222684415657,2.6520144952857225,2.917215944814295,3.2089375392957247,3.5298312932252975,3.8828144225478276,4.271095864802611,4.698205451282872,5.16802599641116,5.684828596052276,6.253311455657505,6.878642601223255,7.566506861345581,8.32315754748014,9.155473302228154,10.07102063245097,11.078122695696068,12.185934965265677,13.404528461792246],"type":"scatter","hovertemplate":"year %{x}<br>log = %{y:.2f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"col ...

# %%
trace = go.Scatter(
    x=spy.date,
    y=compound,
        hovertemplate="%{x}<br>$%{y:.2f}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="",
    yaxis_title="Accumulation from $1",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    yaxis_tickformat=".0f",
    yaxis_type="log",
    width=1000,
    height=460,
    yaxis = dict(
        tickmode = 'array',
        tickvals = [2, 5, 10, 16],
    )
  )

fig.show()
# Out:
# <div>                            <div id="05f4de73-304c-49c6-9773-4d251b01d1a6" class="plotly-graph-div" style="height:460px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05f4de73-304c-49c6-9773-4d251b01d1a6")) {                    Plotly.newPlot(                        "05f4de73-304c-49c6-9773-4d251b01d1a6",                        [{"hovertemplate":"%{x}<br>$%{y:.2f}<extra></extra>","name":"","x":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"y":[1.0039723370704297,1.3859739386930232,1.697782972312623,2.266118534892774,2.916324118936164,3.5109437169487006,3.168924227793312,2.7963056164068876,2.1927332486697413,2.8106790814695124,3.111364712513039,3.261589238171031,3.7783968219087236,3.9728423648359974,2.5110345120373445,3.17273692895274,3.6504285202679094,3.7196034353094007,4.314379552696716,5.708262706274011,6.476808849743964,6.5567517437193334,7.34342310781408,8.937342177739943,8.528996703189474,11.192079399370064,13.243769715121585,17.048540190193208,13.3494737590074],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...

# %%
trace = go.Box(
    x=spy.ret,
    text=spy.date,
    hovertemplate="%{text}<extra></extra>",
    name="",
    )
fig = go.Figure(trace)
fig.update_layout(
    template="plotly_dark",
    yaxis_title="",
    xaxis_title="Annual Return",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat="",
    width=1000,
    height=500,
)

fig.show()
# Out:
# <div>                            <div id="8d5c54d4-28dd-4e6f-b871-48ee06370401" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d5c54d4-28dd-4e6f-b871-48ee06370401")) {                    Plotly.newPlot(                        "8d5c54d4-28dd-4e6f-b871-48ee06370401",                        [{"hovertemplate":"%{text}<extra></extra>","name":"","text":["1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"x":[0.0039723370704296546,0.38049016642955147,0.2249746729824058,0.33475159772983054,0.2869247896929432,0.20389352272320327,-0.09741525832622344,-0.11758520702967334,-0.21584635248585826,0.28181532485753036,0.10697970929015432,0.04828251893898239,0.15845268855114858,0.051462446135831286,-0.36795012702674845,0.26351785040919995,0.15056136137730336,0.018949806757595278,0.15990309927699076,0.3230784720148334,0.13463748657279484,0.01234294477882103,0.1199788240950701,0.21705396060180515,-0.04568981095604985,0.31223868279661926,0.18331627596092637,0.28728757422649687,-0.21697261993807615],"type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666 ...

# %%
from scipy.stats import norm
from scipy.stats import gaussian_kde as kde

density = kde(spy.ret)
grid = np.linspace(np.min(spy.ret), np.max(spy.ret), 100)

trace1 = go.Scatter(
  x=grid,
  y=density(grid),
  mode="lines",
  name="actual"
)

trace2 = go.Scatter(
  x=grid, 
  y=norm.pdf(grid, np.mean(spy.ret), scale=np.std(spy.ret)), 
  mode="lines", 
  name="normal"
)
fig = go.Figure()
fig.add_trace(trace1)
fig.add_trace(trace2)
fig.update_layout(
    template="plotly_dark",
    xaxis_title="Annual Return",
    yaxis_title="",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat="",
    width=1000,
    height=360,
     legend=dict(
        yanchor="top", 
        y=0.99, 
        xanchor="right", 
        x=0.99
    ),
)

fig.show()
# Out:
# <div>                            <div id="abddb145-2a66-46c6-8271-c71d16ffd4c0" class="plotly-graph-div" style="height:360px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abddb145-2a66-46c6-8271-c71d16ffd4c0")) {                    Plotly.newPlot(                        "abddb145-2a66-46c6-8271-c71d16ffd4c0",                        [{"mode":"lines","name":"actual","x":[-0.36795012702674845,-0.3603901240625434,-0.35283012109833833,-0.34527011813413333,-0.33771011516992827,-0.3301501122057232,-0.32259010924151815,-0.3150301062773131,-0.30747010331310803,-0.299910100348903,-0.29235009738469797,-0.2847900944204929,-0.27723009145628785,-0.2696700884920828,-0.26211008552787773,-0.25455008256367273,-0.24699007959946767,-0.2394300766352626,-0.23187007367105755,-0.22431007070685252,-0.21675006774264746,-0.2091900647784424,-0.20163006181423737,-0.1940700588500323,-0.18651005588582725,-0.17895005292162222,-0.17139004995741716,-0.1638300469932121,-0.15627004402900707,-0.148710041064802,-0.14115003810059695,-0.13359003513639192,-0.12603003217218686,-0.1184700292079818,-0.11091002624377677,-0.10335002327957171,-0.09579002031536665,-0.0882300173511616,-0.08067001438695659,-0.07311001142275153,-0.06555000845854647,-0.05799000549434141,-0.05043000253013635,-0.042869999565931294,-0.03530999660172629,-0.02774999363752123,-0.02018999067331617,-0.012629987709111112,-0.005069984744906053,0.002490018219299006,0.01005002118350401,0.01761002414770907,0.02517002711191413,0.03273003007611919,0.04029003304032425,0.047850036004529306,0.05541003896873431,0.06297004193293937,0.07053004489714443,0.07809004786134949,0.08565005082555455,0.0932100537897596,0.10077005675396461,0.10833005971816967,0.11589006268237473,0.12345006564657979,0.13101006861078485,0.1385700715749899,0.1461300745391949,0.15369007750340002,0.16125008046760503,0.16881008343181003,0.17637008639601515,0.18393008936022015,0.19149009232442527,0.19905009528863027,0.20661009825283527,0.2141701012170404,0.2217301041812454,0.2292901071454505,0.2368501101096555,0.24441011307386062,0.25197011603806563,0.25953011900227063,0.26709012196647575,0.27465012493068075,0.28221012789488586,0.28977013085909087,0.2973301338232959,0.304890136787501,0.312450139751706,0.3200101427159111,0.3275701456801161,0.3351301486443212,0.34269015160852623,0.35025015457273123,0.35781015753693635,0.36537016050114135,0.37293016346534646,0.38049016642955147],"y":[0.23354145782488006,0.2456336427225992,0.2579570531092149,0.2705407978045894,0.2834153819416166,0.2966108653026129,0.3101550677834161,0.3240719419958749,0.33838022541492924,0.3530924688985958,0.36821451574471886,0.38374547714238033,0.39967821782732627,0.41600033216787585,0.4326955581351578,0.4497455469450502,0.46713188166514397,0.48483822043490776,0.5028524303129774,0.5211685767103871,0.5397886408401742,0.5587238529643688,0.5779955512794415,0.5976355034720251,0.6176856584487178,0.6381973275274002,0.6592298255302217,0.6808486309560366,0.7031231492110569,0.7261241825536237,0.7499212241459728,0.7745797009611984,0.8001582911779078,0.8267064363293983,0.8542621573392283,0.8828502673590094,0.9124810538766718,0.9431494788585988,0.9748349197992239,1.0075014476284994,1.0410986106852316,1.075562668659108,1.1108181978044578,1.146779970068739,1.1833549951964317,1.2204446073283872,1.257946476819959,1.2957564343009154,1.3337700073214962,1.3718835897168713,1.4099951890226587,1.448004726361081,1.48581389426836,1.5233256087548404,1.5604431201790494,1.5970688710618501,1.6331032058442,1.6684430463633901,1.702980646694569,1.7366025319369132,1.7691887082715387,1.8006122076939874,1.83073900238581,1.8594282933561945,1.8865331485975172,1.9119014403516632,1.9353770116463798,1.9568009909245188,1.976013171464523,1.9928533795766725,2.0071627715004556,2.0187850218654413,2.02756739409371,2.033361712263428,2. ...

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt
plt.style.use('classic')
plt.rcParams.update({'font.size': 26})
fig = plot_acf(spy.ret)
plt.xlabel("Year")
plt.ylabel("Autocorrelation")
plt.title("")

_ = fig.set_size_inches(18,9)

# %%
import statsmodels.formula.api as smf

spy['lag'] = spy.ret.shift()
spy = spy.dropna()

trace = go.Scatter(
  x=spy.lag,
  y=spy.ret,
  text=spy.date,
  mode="markers",
  hovertemplate="%{text}<extra></extra>",
  showlegend=False,
  marker=dict(size=15)
)
fig = go.Figure(trace)

result = smf.ols("ret ~ lag", data=spy).fit()
predict = result.params['Intercept'] + result.params['lag']*spy.lag

trace = go.Scatter(
  x=spy.lag,
  y=predict,
  mode="lines",
  name="regression line",
)

fig.add_trace(trace)

fig.update_layout(
    template="plotly_dark",
    xaxis_title="Lagged Return",
    yaxis_title="Return",
    xaxis_title_font_size=24,
    yaxis_title_font_size=24,
    font_size=20,
    xaxis_tickformat=".0%",
    yaxis_tickformat=".0%",
    width=1000,
    height=520,
)

fig.show()
# Out:
# <div>                            <div id="16f249b9-25db-4ddc-b755-ccedcd3aeb9e" class="plotly-graph-div" style="height:520px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16f249b9-25db-4ddc-b755-ccedcd3aeb9e")) {                    Plotly.newPlot(                        "16f249b9-25db-4ddc-b755-ccedcd3aeb9e",                        [{"hovertemplate":"%{text}<extra></extra>","marker":{"size":15},"mode":"markers","showlegend":false,"text":["1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"x":[0.0039723370704296546,0.38049016642955147,0.2249746729824058,0.33475159772983054,0.2869247896929432,0.20389352272320327,-0.09741525832622344,-0.11758520702967334,-0.21584635248585826,0.28181532485753036,0.10697970929015432,0.04828251893898239,0.15845268855114858,0.051462446135831286,-0.36795012702674845,0.26351785040919995,0.15056136137730336,0.018949806757595278,0.15990309927699076,0.3230784720148334,0.13463748657279484,0.01234294477882103,0.1199788240950701,0.21705396060180515,-0.04568981095604985,0.31223868279661926,0.18331627596092637,0.28728757422649687],"y":[0.38049016642955147,0.2249746729824058,0.33475159772983054,0.2869247896929432,0.20389352272320327,-0.09741525832622344,-0.11758520702967334,-0.21584635248585826,0.28181532485753036,0.10697970929015432,0.04828251893898239,0.15845268855114858,0.051462446135831286,-0.36795012702674845,0.26351785040919995,0.15056136137730336,0.018949806757595278,0.15990309927699076,0.3230784720148334,0.13463748657279484,0.01234294477882103,0.1199788240950701,0.21705396060180515,-0.04568981095604985,0.31223868279661926,0.18331627596092637,0.28728757422649687,-0.21697261993807615],"type":"scatter"},{"mode":"lines","name":"regression line","x":[0.0039723370704296546,0.38049016642955147,0.2249746729824058,0.33475159772983054,0.2869247896929432,0.20389352272320327,-0.09741525832622344,-0.11758520702967334,-0.21584635248585826,0.28181532485753036,0.10697970929015432,0.04828251893898239,0.15845268855114858,0.051462446135831286,-0.36795012702674845,0.26351785040919995,0.15056136137730336,0.018949806757595278,0.15990309927699076,0.3230784720148334,0.13463748657279484,0.01234294477882103,0.1199788240950701,0.21705396060180515,-0.04568981095604985,0.31223868279661926,0.18331627596092637,0.28728757422649687],"y":[0.11277784485723648,0.11751735058551281,0.11555976314992432,0.1169416057164731,0.11633957464920111,0.1152943992690632,0.11150160492465078,0.11124771100525324,0.11001082598828266,0.11627525807248791,0.11407447410722726,0.11333560957489787,0.11472240220262231,0.1133756376479127,0.10809618435774938,0.11604493435818078,0.11462306828686113,0.1129663772396159,0.11474065958489603,0.11679466753219829,0.11442262281000075,0.11288321182817276,0.114238103487502,0.1154600593410402,0.11215271102107621,0.11665821916485143,0.11503537839064167,0.11634414128387506],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tick ...
